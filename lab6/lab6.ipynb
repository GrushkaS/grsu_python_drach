# %% [markdown]
# # Лабораторная работа 6. Основы анализа данных Pandas.

# %% [markdown]
# Создайте таблицу

# %%
table = [[3, 1, 2], [4, 5, 6]]

# %% [markdown]
# Выведите первую строку:

# %%
print(table[0])
# Out:
# [3, 1, 2]

# %% [markdown]
# Подключим библиотеку Pandas

# %%
import pandas as pd

# %% [markdown]
# Давайте сделаем dataframe из нашей таблицы.

# %%
df = pd.DataFrame(table)

# %% [markdown]
# Выведите первый столбец с заголовками.

# %%
df
# Out:
#    0  1  2
# 0  3  1  2
# 1  4  5  6

# %% [markdown]
# Выведите первую строку с заголовками.

# %%
df.head(1)
#df.iloc
# Out:
#    0  1  2
# 0  3  1  2

# %% [markdown]
# Выведите вторую строку.

# %%
df.tail(-1)
#df.iloc
# Out:
#    0  1  2
# 1  4  5  6

# %% [markdown]
# Загрузим файл в Pandas. Выведите результат.

# %%
df = pd.read_csv(
    "lab6_1.csv"
)
df
# Out:
#      task   group10  group2  group3  group4
# 0  python       1.0     2.0     3.0     2.0
# 1     c++       2.3     1.2     2.2     1.2
# 2      c#       2.1     2.3     2.3     2.2
# 3    java       4.0     2.5     2.5     1.2
# 4     php       6.0     5.0     4.0     5.0

# %% [markdown]
# Верхняя строчка выделена полужирным т.к. рассматривается не как строчка с данными, а как строчка с именами столбцов. К столбцам можно обращаться по имени. Обратитесь к столбцу "group10"

# %%
de = df[' group10']
de
# Out:
# 0    1.0
# 1    2.3
# 2    2.1
# 3    4.0
# 4    6.0
# Name:  group10, dtype: float64

# %% [markdown]
# У строк по умолчанию нет имён, и им присваивются номера (левая полужирная колонка). Можно загрузить файл таким образом, чтобы первый столбец рассматривался как столбец с именами строк.

# %%
df = pd.read_csv(
    "lab6_1.csv",
    index_col=0
)

# %%
df
# Out:
#          group10  group2  group3  group4
# task
# python       1.0     2.0     3.0     2.0
# c++          2.3     1.2     2.2     1.2
# c#           2.1     2.3     2.3     2.2
# java         4.0     2.5     2.5     1.2
# php          6.0     5.0     4.0     5.0

# %% [markdown]
# Обратитесь к строке "python".

# %%
df.loc['python']
# Out:
#  group10    1.0
# group2      2.0
# group3      3.0
# group4      2.0
# Name: python, dtype: float64

# %% [markdown]
# Убрать "task" можно следующим образом.

# %%
df.index.name = None
df
# Out:
#          group10  group2  group3  group4
# python       1.0     2.0     3.0     2.0
# c++          2.3     1.2     2.2     1.2
# c#           2.1     2.3     2.3     2.2
# java         4.0     2.5     2.5     1.2
# php          6.0     5.0     4.0     5.0

# %% [markdown]
# Обратитесь к конткретному элементу таблицы.

# %%
df.loc['c#', 'group2']
# Out:
# 2.3

# %% [markdown]
# Переименуйте столбец group10 в group1

# %%
df.rename(columns = {' group10':'group1'}, inplace=True)
df
# Out:
#         group1  group2  group3  group4
# python     1.0     2.0     3.0     2.0
# c++        2.3     1.2     2.2     1.2
# c#         2.1     2.3     2.3     2.2
# java       4.0     2.5     2.5     1.2
# php        6.0     5.0     4.0     5.0

# %% [markdown]
# Сделайте срез из 3й и 4й строки.

# %%
df[2:4]
# Out:
#       group1  group2  group3  group4
# c#       2.1     2.3     2.3     2.2
# java     4.0     2.5     2.5     1.2

# %% [markdown]
# Сделайте срез из 2ого и 3его столбов.

# %%
df[['group2','group3']]
# Out:
#         group2  group3
# python     2.0     3.0
# c++        1.2     2.2
# c#         2.3     2.3
# java       2.5     2.5
# php        5.0     4.0

# %% [markdown]
# Получите все строки, соответствующие отметкам по которым group1 получила оценку выше тройки

# %%
df[df['group1'] > 3]
# Out:
#       group1  group2  group3  group4
# java     4.0     2.5     2.5     1.2
# php      6.0     5.0     4.0     5.0

# %% [markdown]
# Посчитать среднюю отметку для каждого предмета.

# %%
df.mean()
# Out:
# group1    3.08
# group2    2.60
# group3    2.80
# group4    2.32
# dtype: float64

# %% [markdown]
# Посчитать среднюю отметку для каждого языка (используйте транспонирование ".T").

# %%
df.T.mean()
# Out:
# python    2.000
# c++       1.725
# c#        2.225
# java      2.550
# php       5.000
# dtype: float64

# %% [markdown]
# Тоже самое, только используйте направление (axis).

# %%
df.mean(axis = 1)
# Out:
# python    2.000
# c++       1.725
# c#        2.225
# java      2.550
# php       5.000
# dtype: float64

# %% [markdown]
# Найдите min для языков.

# %%
df.T.min()
# Out:
# python    1.0
# c++       1.2
# c#        2.1
# java      1.2
# php       4.0
# dtype: float64

# %% [markdown]
# Найдите max для языков.

# %%
df.T.max()
# Out:
# python    3.0
# c++       2.3
# c#        2.3
# java      4.0
# php       6.0
# dtype: float64

# %% [markdown]
# Тоже самое с группами.

# %%
df.min()
# Out:
# group1    1.0
# group2    1.2
# group3    2.2
# group4    1.2
# dtype: float64

# %%
df.max()
# Out:
# group1    6.0
# group2    5.0
# group3    4.0
# group4    5.0
# dtype: float64

# %% [markdown]
# # Часть 2. Более сложный датафрейм

# %% [markdown]
# Далее будем использовать открытые данные Москвы.

# %%
df = pd.read_csv(
    "lab6_2.csv",
    sep=';'
)

# %% [markdown]
# Таблица большая, выаедем несколько строк df.head()

# %%
df.head()
# Out:
#    ROWNUM                                             Region  \
# 0       1  город Москва (за исключением Троицкого и Новом...
# 1       2  город Москва (за исключением Троицкого и Новом...
# 2       3  город Москва (за исключением Троицкого и Новом...
# 3       4  город Москва (за исключением Троицкого и Новом...
# 4       5  город Москва (за исключением Троицкого и Новом...
#
#               TariffItem UnitOfMeasure   StartDate     EndDate  \
# 0  Горячее водоснабжение     руб/куб.м  01.01.2012  30.06.2012
# 1          Водоотведение     руб/куб.м  01.01.2012  30.06.2012
# 2                    Газ      руб/кв.м  01.07.2012  31.08.2012
# 3         Электроэнергия     руб/кВт.ч  01.07.2012  31.07.2012
# 4         Электроэнергия     руб/кВт.ч  01.01.2012  30.06.2012
#
#   MeasureDeviceAvail StoveType                         ConsumptionTime  \
# 0                 да       NaN                                     NaN
# 1                 да       NaN                                     NaN
# 2                нет       NaN                                     NaN
# 3                 да   газовая  с 07:00 по 23:00 ч (двухтарифный учет)
# 4                 да   газовая  с 23:00 по 07:00 ч (двухтарифный учет)
#
#                            ConsumptionTarget  \
# 0                                        NaN
# 1                                        NaN
# 2  дома с отоплением от газовых нагревателей
# 3                           на бытовые нужды
# 4                           на бытовые нужды
#
#                                               Agency  TariffValue  global_id  \
# 0  ОАО «МОЭК» и иные, кроме ОАО «Мосэнерго» и ОАО...       105.45   19693618
# 1                                МГУП «Мосводоканал»        16.65   19693667
# 2                  ООО «Газпром межрегионгаз Москва»        25.61   19693682
# 3                                ОАО «Мосэнергосбыт»         4.03   19693607
# 4                                ОАО «Мосэнергосбыт»         0.95   19693669
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %% [markdown]
# Выведите столбец ROWNUM

# %%
df['ROWNUM']
# Out:
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
#       ..
# 66    67
# 67    68
# 68    69
# 69    70
# 70    71
# Name: ROWNUM, Length: 71, dtype: int64

# %% [markdown]
# Не все так просто. Ответ - нет такого столбца. Но он же есть!

# %%
list(df)
# Out:
# ['ROWNUM',
#  'Region',
#  'TariffItem',
#  'UnitOfMeasure',
#  'StartDate',
#  'EndDate',
#  'MeasureDeviceAvail',
#  'StoveType',
#  'ConsumptionTime',
#  'ConsumptionTarget',
#  'Agency',
#  'TariffValue',
#  'global_id',
#  'Unnamed: 13']

# %% [markdown]
# Перед ROWNUM есть невидимый символ, кодирующийся как \ufeff. Чтобы его не считать, нужно использовать encoding='utf-8-sig'

# %%
df = pd.read_csv(
    "lab6_2.csv",
    sep=';',
    encoding = 'utf-8-sig'
)

# %% [markdown]
# Покажите, что ошибка исправлена (df['ROWNUM'])

# %%
df['ROWNUM']
# Out:
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
#       ..
# 66    67
# 67    68
# 68    69
# 69    70
# 70    71
# Name: ROWNUM, Length: 71, dtype: int64

# %% [markdown]
# Данных столбец нам в этом виде не понадобится. Сделаейте его индексом строк.

# %%
#df = pd.read_csv(
#    "lab6_2.csv",
#    sep=';',
#    encoding = 'utf-8-sig',
#    index_col = 0
#)
df = df.set_index('ROWNUM')

# %% [markdown]
# Продемонстрируйте.

# %%
df
# Out:
#                                                    Region  \
# ROWNUM
# 1       город Москва (за исключением Троицкого и Новом...
# 2       город Москва (за исключением Троицкого и Новом...
# 3       город Москва (за исключением Троицкого и Новом...
# 4       город Москва (за исключением Троицкого и Новом...
# 5       город Москва (за исключением Троицкого и Новом...
# ...                                                   ...
# 67      город Москва (за исключением Троицкого и Новом...
# 68      город Москва (за исключением Троицкого и Новом...
# 69      город Москва (за исключением Троицкого и Новом...
# 70      город Москва (за исключением Троицкого и Новом...
# 71      город Москва (за исключением Троицкого и Новом...
#
#                    TariffItem UnitOfMeasure   StartDate     EndDate  \
# ROWNUM
# 1       Горячее водоснабжение     руб/куб.м  01.01.2012  30.06.2012
# 2               Водоотведение     руб/куб.м  01.01.2012  30.06.2012
# 3                         Газ      руб/кв.м  01.07.2012  31.08.2012
# 4              Электроэнергия     руб/кВт.ч  01.07.2012  31.07.2012
# 5              Электроэнергия     руб/кВт.ч  01.01.2012  30.06.2012
# ...                       ...           ...         ...         ...
# 67             Электроэнергия     руб/кВт.ч  01.07.2012  31.07.2012
# 68             Электроэнергия     руб/кВт.ч  01.01.2012  30.06.2012
# 69             Электроэнергия     руб/кВт.ч  01.07.2012  31.07.2012
# 70             Электроэнергия     руб/кВт.ч  01.07.2012  31.07.2012
# 71                        Газ     руб/куб.м  15.01.2012  30.06.2012
#
#        MeasureDeviceAvail      StoveType  \
# ROWNUM
# 1                      да            NaN
# 2                      да            NaN
# 3                     нет            NaN
# 4                      да        газовая
# 5                      да        газовая
# ...                   ...            ...
# 67                     да        газовая
# 68                     да  электрическая
# 69                     да  электрическая
# 70                     да  электрическая
# 71                 да/нет            NaN
#
#                                   ConsumptionTime  \
# ROWNUM
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4          с 07:00 по 23:00 ч (двухтарифный учет)
# 5          с 23:00 по 07:00 ч (двухтарифный учет)
# ...                                           ...
# 67        с 17:00 по 21:00 ч (многотарифный учет)
# 68      без дифференциации по времени потребления
# 69        с 17:00 по 21:00 ч (многотарифный учет)
# 70         с 07:00 по 23:00 ч (двухтарифный учет)
# 71                                            NaN
#
#                                         ConsumptionTarget  \
# ROWNUM
# 1                                                     NaN
# 2                                                     NaN
# 3               дома с отоплением от газовых нагревателей
# 4                                        на бытовые нужды
# 5                                        на бытовые нужды
# ...                                                   ...
# 67                                       на бытовые нужды
# 68                                       на бытовые нужды
# 69                                       на бытовые нужды
# 70                                       на бытовые нужды
# 71      на приготовление пищи и нагрев воды с использо...
#
#                                                    Agency  TariffValue  \
# ROWNUM
# 1       ОАО «МОЭК» и иные, кроме ОАО «Мосэнерго» и ОАО...       105.45
# 2                                     МГУП «Мосводоканал»        16.65
# 3                       ООО «Газпром межрегионгаз Москва»        25.61
# 4                                     ОАО «Мосэнергосбыт»         4.03
# 5                                     ОАО «Мосэнергосбыт»         0.95
# ...                                                   ...          ...
# 67                                    ОАО «Мосэнергосбыт»         4.03
# 68                                    ОАО «Мосэнергосбыт»         2.65
# 69                                    ОАО «Мосэнергосбыт»         2.82
# 70                                    ОАО «Мосэнергосбыт»         2.82
# 71                      ООО «Газпром межрегионгаз Москва»         4.09
#
#         global_id  Unnamed: 13
# ROWNUM
# 1        19693618          NaN
# 2        19693667          NaN
# 3        19693682          NaN
# 4        19693607          NaN
# 5        19693669          NaN
# ...           ...          ...
# 67       19693301          NaN
# 68       19693599          NaN
# 69       19693614          NaN
# 70       19693676          NaN
# 71       19693683          NaN
#
# [71 rows x 13 columns]

# %% [markdown]
#  В таблице собраны разные данные: тарифы на электроэнергию, газ т.д. Запишите в q_gas данные за газ.

# %%
q_gas = df[df['TariffItem'] == 'Газ']
q_gas.head()
# Out:
#                                                    Region TariffItem  \
# ROWNUM
# 3       город Москва (за исключением Троицкого и Новом...        Газ
# 7                                            город Москва        Газ
# 8       город Москва (за исключением Троицкого и Новом...        Газ
# 11      город Москва (за исключением Троицкого и Новом...        Газ
# 12      город Москва (за исключением Троицкого и Новом...        Газ
#
#          UnitOfMeasure   StartDate     EndDate MeasureDeviceAvail StoveType  \
# ROWNUM
# 3             руб/кв.м  01.07.2012  31.08.2012                нет       NaN
# 7            руб/куб.м  11.01.2011  15.01.2012                 да       NaN
# 8            руб/куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 11           руб/куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 12      руб/1000 куб.м  15.01.2012  30.06.2012             да/нет       NaN
#
#        ConsumptionTime                                  ConsumptionTarget  \
# ROWNUM
# 3                  NaN          дома с отоплением от газовых нагревателей
# 7                  NaN  на приготовление пищи и горячее водоснабжение ...
# 8                  NaN  на нагрев воды с использованием газового водон...
# 11                 NaN  на нагрев воды с использованием газового водон...
# 12                 NaN  на отопление с одновременным использованием га...
#
#                                    Agency  TariffValue  global_id  Unnamed: 13
# ROWNUM
# 3       ООО «Газпром межрегионгаз Москва»        25.61   19693682          NaN
# 7                      ООО «Мосрегионгаз»         4.09   19693595          NaN
# 8       ООО «Газпром межрегионгаз Москва»         4.09   19693684          NaN
# 11      ООО «Газпром межрегионгаз Москва»         4.70   19693624          NaN
# 12      ООО «Газпром межрегионгаз Москва»      2930.00   19693625          NaN

# %% [markdown]
# Теперь, используя groupby, запишите в groups различные тарифы. Теперь выведите тарифы за Водоотведение.

# %%
groups = df.groupby('TariffItem')
groups.get_group('Водоотведение').head()
# Out:
#                                                    Region     TariffItem  \
# ROWNUM
# 2       город Москва (за исключением Троицкого и Новом...  Водоотведение
# 27      город Москва (за исключением Троицкого и Новом...  Водоотведение
# 43      город Москва (за исключением Троицкого и Новом...  Водоотведение
#
#        UnitOfMeasure   StartDate     EndDate MeasureDeviceAvail StoveType  \
# ROWNUM
# 2          руб/куб.м  01.01.2012  30.06.2012                 да       NaN
# 27         руб/куб.м  01.09.2012  31.12.2012                 да       NaN
# 43         руб/куб.м  01.07.2012  31.08.2012                 да       NaN
#
#        ConsumptionTime ConsumptionTarget               Agency  TariffValue  \
# ROWNUM
# 2                  NaN               NaN  МГУП «Мосводоканал»        16.65
# 27                 NaN               NaN  МГУП «Мосводоканал»        19.00
# 43                 NaN               NaN  МГУП «Мосводоканал»        18.20
#
#         global_id  Unnamed: 13
# ROWNUM
# 2        19693667          NaN
# 27       19693387          NaN
# 43       19693668          NaN

# %% [markdown]
# Выведите список групп.

# %%
groups.groups.keys()
# Out:
# dict_keys(['Водоотведение', 'Газ', 'Горячее водоснабжение', 'Отопление', 'Твердое топливо', 'Холодное водоснабжение', 'Электроэнергия'])

# %% [markdown]
# Посчитайте средние тарифы.

# %%
df.groupby('TariffItem').mean()
# Out:
#                         TariffValue     global_id  Unnamed: 13
# TariffItem
# Водоотведение             17.950000  1.969357e+07          NaN
# Газ                      651.415000  1.969359e+07          NaN
# Горячее водоснабжение    100.095000  1.969352e+07          NaN
# Отопление               1208.423333  1.969363e+07          NaN
# Твердое топливо         1126.000000  1.969363e+07          NaN
# Холодное водоснабжение    25.223333  1.969364e+07          NaN
# Электроэнергия             2.571250  1.969359e+07          NaN

# %% [markdown]
# Далее приведем в порядок тарифы за газ. Вычислите кол-во различных UnitOfMeasure (единица измерения).

# %%
q_gas['UnitOfMeasure'].value_counts()
# Out:
# руб/куб.м         8
# руб/чел           6
# руб/1000 куб.м    4
# руб/кв.м          2
# Name: UnitOfMeasure, dtype: int64

# %% [markdown]
# Замените руб/кв.м на руб/куб.м (это ошибка).

# %%
qkvm = q_gas['UnitOfMeasure'] == 'руб/кв.м'
q_gas[qkvm]
# Out:
#                                                    Region TariffItem  \
# ROWNUM
# 3       город Москва (за исключением Троицкого и Новом...        Газ
# 52      город Москва (за исключением Троицкого и Новом...        Газ
#
#        UnitOfMeasure   StartDate     EndDate MeasureDeviceAvail StoveType  \
# ROWNUM
# 3           руб/кв.м  01.07.2012  31.08.2012                нет       NaN
# 52          руб/кв.м  01.01.2012  30.06.2012                нет       NaN
#
#        ConsumptionTime                          ConsumptionTarget  \
# ROWNUM
# 3                  NaN  дома с отоплением от газовых нагревателей
# 52                 NaN  дома с отоплением от газовых нагревателей
#
#                                    Agency  TariffValue  global_id  Unnamed: 13
# ROWNUM
# 3       ООО «Газпром межрегионгаз Москва»        25.61   19693682          NaN
# 52      ООО «Газпром межрегионгаз Москва»        22.27   19693622          NaN

# %%
q_gas = q_gas.copy()
q_gas.loc[qkvm, 'UnitOfMeasure'] = "руб/куб.м"
q_gas['UnitOfMeasure'].value_counts()
# Out:
# руб/куб.м         10
# руб/чел            6
# руб/1000 куб.м     4
# Name: UnitOfMeasure, dtype: int64

# %% [markdown]
# Все значения в строках где руб/1000 куб.м умножьте на 1000.

# %%
q_gas.loc[q_gas['UnitOfMeasure'] == "руб/1000 куб.м", "TariffValue"] *= 1000
q_gas
# Out:
#                                                    Region TariffItem  \
# ROWNUM
# 3       город Москва (за исключением Троицкого и Новом...        Газ
# 7                                            город Москва        Газ
# 8       город Москва (за исключением Троицкого и Новом...        Газ
# 11      город Москва (за исключением Троицкого и Новом...        Газ
# 12      город Москва (за исключением Троицкого и Новом...        Газ
# 13      город Москва (за исключением Троицкого и Новом...        Газ
# 14                                           город Москва        Газ
# 15      город Москва (за исключением Троицкого и Новом...        Газ
# 22      город Москва (за исключением Троицкого и Новом...        Газ
# 23      город Москва (за исключением Троицкого и Новом...        Газ
# 24      город Москва (за исключением Троицкого и Новом...        Газ
# 32      город Москва (за исключением Троицкого и Новом...        Газ
# 36      город Москва (за исключением Троицкого и Новом...        Газ
# 46      город Москва (за исключением Троицкого и Новом...        Газ
# 52      город Москва (за исключением Троицкого и Новом...        Газ
# 60      город Москва (за исключением Троицкого и Новом...        Газ
# 62      город Москва (за исключением Троицкого и Новом...        Газ
# 64      город Москва (за исключением Троицкого и Новом...        Газ
# 66      город Москва (за исключением Троицкого и Новом...        Газ
# 71      город Москва (за исключением Троицкого и Новом...        Газ
#
#          UnitOfMeasure   StartDate     EndDate MeasureDeviceAvail StoveType  \
# ROWNUM
# 3            руб/куб.м  01.07.2012  31.08.2012                нет       NaN
# 7            руб/куб.м  11.01.2011  15.01.2012                 да       NaN
# 8            руб/куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 11           руб/куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 12      руб/1000 куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 13           руб/куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 14           руб/куб.м  11.01.2011  15.01.2012                 да       NaN
# 15             руб/чел  01.01.2012  30.06.2012                нет       NaN
# 22           руб/куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 23             руб/чел  01.07.2012  31.12.2012                нет       NaN
# 24           руб/куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 32             руб/чел  01.01.2012  30.06.2012                нет       NaN
# 36             руб/чел  01.07.2012  31.12.2012                нет       NaN
# 46             руб/чел  01.07.2012  31.12.2012                нет       NaN
# 52           руб/куб.м  01.01.2012  30.06.2012                нет       NaN
# 60      руб/1000 куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 62      руб/1000 куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 64      руб/1000 куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 66             руб/чел  01.01.2012  30.06.2012                нет       NaN
# 71           руб/куб.м  15.01.2012  30.06.2012             да/нет       NaN
#
#        ConsumptionTime                                  ConsumptionTarget  \
# ROWNUM
# 3                  NaN          дома с отоплением от газовых нагревателей
# 7                  NaN  на приготовление пищи и горячее водоснабжение ...
# 8                  NaN  на нагрев воды с использованием газового водон...
# 11                 NaN  на нагрев воды с использованием газового водон...
# 12                 NaN  на отопление с одновременным использованием га...
# 13                 NaN  на приготовление пищи и нагрев воды с использо...
# 14                 NaN  на отопление жилых помещений, а также в случае...
# 15                 NaN  при наличии в квартире газовой плиты и отсутст...
# 22                 NaN  на приготовление пищи и нагрев воды с использо...
# 23                 NaN  при наличии в квартире газовой плиты и газовог...
# 24                 NaN  на приготовление пищи и нагрев воды с использо...
# 32                 NaN  при наличии в квартире газовой плиты и газовог...
# 36                 NaN  при наличии в квартире газовой плиты и отсутст...
# 46                 NaN  при наличии в квартире газовой плиты и централ...
# 52                 NaN          дома с отоплением от газовых нагревателей
# 60                 NaN  на отопление с одновременным использованием га...
# 62                 NaN  на отопление и (или) выработку электрической э...
# 64                 NaN  на отопление и (или) выработку электрической э...
# 66                 NaN  при наличии в квартире газовой плиты и централ...
# 71                 NaN  на приготовление пищи и нагрев воды с использо...
#
#                                    Agency  TariffValue  global_id  Unnamed: 13
# ROWNUM
# 3       ООО «Газпром межрегионгаз Москва»        25.61   19693682          NaN
# 7                      ООО «Мосрегионгаз»         4.09   19693595          NaN
# 8       ООО «Газпром межрегионгаз Москва»         4.09   19693684          NaN
# 11      ООО «Газпром межрегионгаз Москва»         4.70   19693624          NaN
# 12      ООО «Газпром межрегионгаз Москва»   2930000.00   19693625          NaN
# 13      ООО «Газпром межрегионгаз Москва»         4.70   19693623          NaN
# 14                     ООО «Мосрегионгаз»         2.93   19693594          NaN
# 15      ООО «Газпром межрегионгаз Москва»        42.49   19693680          NaN
# 22      ООО «Газпром межрегионгаз Москва»         4.09   19693685          NaN
# 23      ООО «Газпром межрегионгаз Москва»        97.76   19693306          NaN
# 24      ООО «Газпром межрегионгаз Москва»         4.70   19693307          NaN
# 32      ООО «Газпром межрегионгаз Москва»        84.98   19693621          NaN
# 36      ООО «Газпром межрегионгаз Москва»        48.88   19693681          NaN
# 46      ООО «Газпром межрегионгаз Москва»        39.01   19693305          NaN
# 52      ООО «Газпром межрегионгаз Москва»        22.27   19693622          NaN
# 60      ООО «Газпром межрегионгаз Москва»   3370000.00   19693626          NaN
# 62      ООО «Газпром межрегионгаз Москва»   2930000.00   19693627          NaN
# 64      ООО «Газпром межрегионгаз Москва»   3370000.00   19693628          NaN
# 66      ООО «Газпром межрегионгаз Москва»        33.91   19693679          NaN
# 71      ООО «Газпром межрегионгаз Москва»         4.09   19693683          NaN

# %% [markdown]
# Измените единицу измерения на руб/куб.м.

# %%
q_gas.loc[q_gas['UnitOfMeasure'] == 'руб/1000 куб.м', 'UnitOfMeasure'] = "руб/куб.м"
q_gas
# Out:
#                                                    Region TariffItem  \
# ROWNUM
# 3       город Москва (за исключением Троицкого и Новом...        Газ
# 7                                            город Москва        Газ
# 8       город Москва (за исключением Троицкого и Новом...        Газ
# 11      город Москва (за исключением Троицкого и Новом...        Газ
# 12      город Москва (за исключением Троицкого и Новом...        Газ
# 13      город Москва (за исключением Троицкого и Новом...        Газ
# 14                                           город Москва        Газ
# 15      город Москва (за исключением Троицкого и Новом...        Газ
# 22      город Москва (за исключением Троицкого и Новом...        Газ
# 23      город Москва (за исключением Троицкого и Новом...        Газ
# 24      город Москва (за исключением Троицкого и Новом...        Газ
# 32      город Москва (за исключением Троицкого и Новом...        Газ
# 36      город Москва (за исключением Троицкого и Новом...        Газ
# 46      город Москва (за исключением Троицкого и Новом...        Газ
# 52      город Москва (за исключением Троицкого и Новом...        Газ
# 60      город Москва (за исключением Троицкого и Новом...        Газ
# 62      город Москва (за исключением Троицкого и Новом...        Газ
# 64      город Москва (за исключением Троицкого и Новом...        Газ
# 66      город Москва (за исключением Троицкого и Новом...        Газ
# 71      город Москва (за исключением Троицкого и Новом...        Газ
#
#        UnitOfMeasure   StartDate     EndDate MeasureDeviceAvail StoveType  \
# ROWNUM
# 3          руб/куб.м  01.07.2012  31.08.2012                нет       NaN
# 7          руб/куб.м  11.01.2011  15.01.2012                 да       NaN
# 8          руб/куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 11         руб/куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 12         руб/куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 13         руб/куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 14         руб/куб.м  11.01.2011  15.01.2012                 да       NaN
# 15           руб/чел  01.01.2012  30.06.2012                нет       NaN
# 22         руб/куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 23           руб/чел  01.07.2012  31.12.2012                нет       NaN
# 24         руб/куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 32           руб/чел  01.01.2012  30.06.2012                нет       NaN
# 36           руб/чел  01.07.2012  31.12.2012                нет       NaN
# 46           руб/чел  01.07.2012  31.12.2012                нет       NaN
# 52         руб/куб.м  01.01.2012  30.06.2012                нет       NaN
# 60         руб/куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 62         руб/куб.м  15.01.2012  30.06.2012             да/нет       NaN
# 64         руб/куб.м  01.07.2012  31.12.2012             да/нет       NaN
# 66           руб/чел  01.01.2012  30.06.2012                нет       NaN
# 71         руб/куб.м  15.01.2012  30.06.2012             да/нет       NaN
#
#        ConsumptionTime                                  ConsumptionTarget  \
# ROWNUM
# 3                  NaN          дома с отоплением от газовых нагревателей
# 7                  NaN  на приготовление пищи и горячее водоснабжение ...
# 8                  NaN  на нагрев воды с использованием газового водон...
# 11                 NaN  на нагрев воды с использованием газового водон...
# 12                 NaN  на отопление с одновременным использованием га...
# 13                 NaN  на приготовление пищи и нагрев воды с использо...
# 14                 NaN  на отопление жилых помещений, а также в случае...
# 15                 NaN  при наличии в квартире газовой плиты и отсутст...
# 22                 NaN  на приготовление пищи и нагрев воды с использо...
# 23                 NaN  при наличии в квартире газовой плиты и газовог...
# 24                 NaN  на приготовление пищи и нагрев воды с использо...
# 32                 NaN  при наличии в квартире газовой плиты и газовог...
# 36                 NaN  при наличии в квартире газовой плиты и отсутст...
# 46                 NaN  при наличии в квартире газовой плиты и централ...
# 52                 NaN          дома с отоплением от газовых нагревателей
# 60                 NaN  на отопление с одновременным использованием га...
# 62                 NaN  на отопление и (или) выработку электрической э...
# 64                 NaN  на отопление и (или) выработку электрической э...
# 66                 NaN  при наличии в квартире газовой плиты и централ...
# 71                 NaN  на приготовление пищи и нагрев воды с использо...
#
#                                    Agency  TariffValue  global_id  Unnamed: 13
# ROWNUM
# 3       ООО «Газпром межрегионгаз Москва»        25.61   19693682          NaN
# 7                      ООО «Мосрегионгаз»         4.09   19693595          NaN
# 8       ООО «Газпром межрегионгаз Москва»         4.09   19693684          NaN
# 11      ООО «Газпром межрегионгаз Москва»         4.70   19693624          NaN
# 12      ООО «Газпром межрегионгаз Москва»   2930000.00   19693625          NaN
# 13      ООО «Газпром межрегионгаз Москва»         4.70   19693623          NaN
# 14                     ООО «Мосрегионгаз»         2.93   19693594          NaN
# 15      ООО «Газпром межрегионгаз Москва»        42.49   19693680          NaN
# 22      ООО «Газпром межрегионгаз Москва»         4.09   19693685          NaN
# 23      ООО «Газпром межрегионгаз Москва»        97.76   19693306          NaN
# 24      ООО «Газпром межрегионгаз Москва»         4.70   19693307          NaN
# 32      ООО «Газпром межрегионгаз Москва»        84.98   19693621          NaN
# 36      ООО «Газпром межрегионгаз Москва»        48.88   19693681          NaN
# 46      ООО «Газпром межрегионгаз Москва»        39.01   19693305          NaN
# 52      ООО «Газпром межрегионгаз Москва»        22.27   19693622          NaN
# 60      ООО «Газпром межрегионгаз Москва»   3370000.00   19693626          NaN
# 62      ООО «Газпром межрегионгаз Москва»   2930000.00   19693627          NaN
# 64      ООО «Газпром межрегионгаз Москва»   3370000.00   19693628          NaN
# 66      ООО «Газпром межрегионгаз Москва»        33.91   19693679          NaN
# 71      ООО «Газпром межрегионгаз Москва»         4.09   19693683          NaN

# %% [markdown]
# Повторно пересчитайте тарифы. Строк с "руб/куб.м" должно быть 12.

# %%
q_gas['UnitOfMeasure'].value_counts() 
#как-то не 12
# Out:
# руб/куб.м    14
# руб/чел       6
# Name: UnitOfMeasure, dtype: int64

# %% [markdown]
# Для всех таких строк вызовите метод describe().

# %%
q_gas.loc[q_gas['UnitOfMeasure'] == 'руб/куб.м'].describe()
# Out:
#         TariffValue     global_id  Unnamed: 13
# count  1.400000e+01  1.400000e+01          0.0
# mean   9.000058e+05  1.969361e+07          NaN
# std    1.481773e+06  9.413788e+01          NaN
# min    2.930000e+00  1.969331e+07          NaN
# 25%    4.090000e+00  1.969362e+07          NaN
# 50%    4.700000e+00  1.969363e+07          NaN
# 75%    2.197506e+06  1.969367e+07          NaN
# max    3.370000e+06  1.969368e+07          NaN

# %% [markdown]
# # Часть 3. Более сложные запросы

# %% [markdown]
# Из исходной таблицы сделайте выборку тех строк, в которых в качестве единицы измерения указаны руб/кв.м и указан тариф на газ.

# %%
df = pd.read_csv(
    "lab6_2.csv",
    sep=';'
)
q_gas = df.loc[df['TariffItem'] == 'Газ']
q_gas = df.loc[df['UnitOfMeasure'] == 'руб/кв.м']
q_gas
# Out:
#     ROWNUM                                             Region TariffItem  \
# 2        3  город Москва (за исключением Троицкого и Новом...        Газ
# 51      52  город Москва (за исключением Троицкого и Новом...        Газ
#
#    UnitOfMeasure   StartDate     EndDate MeasureDeviceAvail StoveType  \
# 2       руб/кв.м  01.07.2012  31.08.2012                нет       NaN
# 51      руб/кв.м  01.01.2012  30.06.2012                нет       NaN
#
#    ConsumptionTime                          ConsumptionTarget  \
# 2              NaN  дома с отоплением от газовых нагревателей
# 51             NaN  дома с отоплением от газовых нагревателей
#
#                                Agency  TariffValue  global_id  Unnamed: 13
# 2   ООО «Газпром межрегионгаз Москва»        25.61   19693682          NaN
# 51  ООО «Газпром межрегионгаз Москва»        22.27   19693622          NaN

# %% [markdown]
# Сделайте такой же запрос через query.

# %%
df.query('TariffItem == "Газ" and UnitOfMeasure == "руб/кв.м"')
# Out:
#     ROWNUM                                             Region TariffItem  \
# 2        3  город Москва (за исключением Троицкого и Новом...        Газ
# 51      52  город Москва (за исключением Троицкого и Новом...        Газ
#
#    UnitOfMeasure   StartDate     EndDate MeasureDeviceAvail StoveType  \
# 2       руб/кв.м  01.07.2012  31.08.2012                нет       NaN
# 51      руб/кв.м  01.01.2012  30.06.2012                нет       NaN
#
#    ConsumptionTime                          ConsumptionTarget  \
# 2              NaN  дома с отоплением от газовых нагревателей
# 51             NaN  дома с отоплением от газовых нагревателей
#
#                                Agency  TariffValue  global_id  Unnamed: 13
# 2   ООО «Газпром межрегионгаз Москва»        25.61   19693682          NaN
# 51  ООО «Газпром межрегионгаз Москва»        22.27   19693622          NaN

# %% [markdown]
# Далее использовать будем открытые данные Москвы за 2016 год. Используйте для этого файл tariff.json. Преобразуйте в необходимый формат.

# %%
df = pd.read_json('tariff.json')
df
# Out:
#        ID                                             Region  \
# 0    3563  город Москва (за исключением Троицкого и Новом...
# 1    3564  город Москва (за исключением Троицкого и Новом...
# 2    3565  город Москва (за исключением Троицкого и Новом...
# 3    3584                       Троицкий и Новомосковский АО
# 4    3585                       Троицкий и Новомосковский АО
# ..    ...                                                ...
# 464  3914                       Троицкий и Новомосковский АО
# 465  3915                       Троицкий и Новомосковский АО
# 466  3916                       Троицкий и Новомосковский АО
# 467  4327                       Троицкий и Новомосковский АО
# 468  4328                       Троицкий и Новомосковский АО
#
#                  TariffItem  global_id UnitOfMeasure   StartDate     EndDate  \
# 0     Горячее водоснабжение  170861214     руб/куб.м  01.01.2016  30.06.2016
# 1     Горячее водоснабжение  170861215     руб/куб.м  01.07.2016  31.12.2016
# 2     Горячее водоснабжение  170861216     руб/куб.м  01.01.2016  30.06.2016
# 3     Горячее водоснабжение  170861235     руб/куб.м  01.07.2016  31.12.2016
# 4     Горячее водоснабжение  170861236     руб/куб.м  01.01.2016  30.06.2016
# ..                      ...        ...           ...         ...         ...
# 464           Водоотведение  276301176     руб/куб.м  22.08.2016  31.12.2016
# 465           Водоотведение  276301271     руб/куб.м  22.08.2016  31.12.2016
# 466  Холодное водоснабжение  276301311     руб/куб.м  03.10.2016  31.12.2016
# 467           Водоотведение  344191727     руб/куб.м  01.01.2016  30.06.2016
# 468           Водоотведение  344191729     руб/куб.м  01.07.2016  31.12.2016
#
#     MeasureDeviceAvail StoveType ConsumptionTime  \
# 0               да/нет
# 1               да/нет
# 2               да/нет
# 3               да/нет
# 4               да/нет
# ..                 ...       ...             ...
# 464             да/нет
# 465             да/нет
# 466             да/нет
# 467             да/нет
# 468             да/нет
#
#                         ConsumptionTarget  \
# 0
# 1
# 2
# 3    для систем ГВС с полотенцесушителями
# 4    для систем ГВС с полотенцесушителями
# ..                                    ...
# 464
# 465     Хозяйственно-бытовые сточные воды
# 466
# 467
# 468
#
#                                                 Agency  TariffValue
# 0             ОАО «МОЭК» и иные, кроме ОАО «Мосэнерго»       151.36
# 1                                      ОАО «Мосэнерго»       130.27
# 2                                      ОАО «Мосэнерго»       120.82
# 3    ООО «ТСК Новая Москва» на территории поселений...       169.59
# 4    ООО «ТСК Новая Москва» на территории поселений...       158.83
# ..                                                 ...          ...
# 464                      ООО «Комплексные системы» «С»       212.74
# 465                      ООО «Комплексные системы» «С»       107.75
# 466                                ООО «АрДиАй Ресурс»        29.22
# 467                       МУП «Водоканал» г. Подольска        11.00
# 468                       МУП «Водоканал» г. Подольска        13.77
#
# [469 rows x 13 columns]

# %% [markdown]
# Вычислите средний тарифф.

# %%
df["TariffValue"].mean()
# Out:
# 401.73393176972274

# %% [markdown]
# Придумайте себе два запроса и реализуйте их ниже.

# %%
df.query('TariffItem == "Водоотведение"')
# Out:
#        ID                        Region     TariffItem  global_id  \
# 196  3790  Троицкий и Новомосковский АО  Водоотведение  170861443
# 197  3791  Троицкий и Новомосковский АО  Водоотведение  170861444
# 198  3792  Троицкий и Новомосковский АО  Водоотведение  170861445
# 199  3793  Троицкий и Новомосковский АО  Водоотведение  170861446
# 200  3794  Троицкий и Новомосковский АО  Водоотведение  170861447
# ..    ...                           ...            ...        ...
# 462  3912  Троицкий и Новомосковский АО  Водоотведение  276300954
# 464  3914  Троицкий и Новомосковский АО  Водоотведение  276301176
# 465  3915  Троицкий и Новомосковский АО  Водоотведение  276301271
# 467  4327  Троицкий и Новомосковский АО  Водоотведение  344191727
# 468  4328  Троицкий и Новомосковский АО  Водоотведение  344191729
#
#     UnitOfMeasure   StartDate     EndDate MeasureDeviceAvail StoveType  \
# 196     руб/куб.м  01.01.2016  30.06.2016             да/нет
# 197     руб/куб.м  01.07.2016  31.12.2016             да/нет
# 198     руб/куб.м  01.01.2016  30.06.2016             да/нет
# 199     руб/куб.м  01.07.2016  31.12.2016             да/нет
# 200     руб/куб.м  01.01.2016  30.06.2016             да/нет
# ..            ...         ...         ...                ...       ...
# 462     руб/куб.м  22.08.2016  31.12.2016             да/нет
# 464     руб/куб.м  22.08.2016  31.12.2016             да/нет
# 465     руб/куб.м  22.08.2016  31.12.2016             да/нет
# 467     руб/куб.м  01.01.2016  30.06.2016             да/нет
# 468     руб/куб.м  01.07.2016  31.12.2016             да/нет
#
#     ConsumptionTime                  ConsumptionTarget  \
# 196
# 197
# 198
# 199
# 200
# ..              ...                                ...
# 462                  Хозяйственно-бытовые сточные воды
# 464
# 465                  Хозяйственно-бытовые сточные воды
# 467
# 468
#
#                                                 Agency  TariffValue
# 196  АО «ГУ ЖКХ» поселок Ватутинки-1 (кроме военног...        14.83
# 197  АО «ГУ ЖКХ» поселок Ватутинки-1 (кроме военног...        15.81
# 198  АО «ГУ ЖКХ» поселок Ватутинки-1 (военный город...        25.44
# 199  АО «ГУ ЖКХ» поселок Ватутинки-1 (военный город...        27.99
# 200                           АО «ГУ ЖКХ» п/о Приволье        10.77
# ..                                                 ...          ...
# 462                      ООО «Комплексные системы» «А»       230.90
# 464                      ООО «Комплексные системы» «С»       212.74
# 465                      ООО «Комплексные системы» «С»       107.75
# 467                       МУП «Водоканал» г. Подольска        11.00
# 468                       МУП «Водоканал» г. Подольска        13.77
#
# [80 rows x 13 columns]

# %%
df.query('TariffItem == "Водоотведение" and Region == "город Москва (за исключением Троицкого и Новомосковского АО)"')
# Out:
#        ID                                             Region     TariffItem  \
# 317  3758  город Москва (за исключением Троицкого и Новом...  Водоотведение
# 318  3759  город Москва (за исключением Троицкого и Новом...  Водоотведение
# 319  3760  город Москва (за исключением Троицкого и Новом...  Водоотведение
# 320  3761  город Москва (за исключением Троицкого и Новом...  Водоотведение
#
#      global_id UnitOfMeasure   StartDate     EndDate MeasureDeviceAvail  \
# 317  170861570     руб/куб.м  01.01.2016  30.06.2016             да/нет
# 318  170861571     руб/куб.м  01.01.2016  30.06.2016             да/нет
# 319  170861572     руб/куб.м  01.01.2016  30.06.2016             да/нет
# 320  170861573     руб/куб.м  01.07.2016  31.12.2016             да/нет
#
#     StoveType ConsumptionTime ConsumptionTarget  \
# 317
# 318
# 319
# 320
#
#                                                 Agency  TariffValue
# 317  ОАО «РЖД» (Московского территориального участк...        25.00
# 318  ОАО «РЖД» (Московского территориального участк...        26.31
# 319  АО «Мосводоканал» за исключением Новомосковско...        21.90
# 320  АО «Мосводоканал» за исключением Новомосковско...        23.43
